# %% [markdown]
# <a href="https://colab.research.google.com/github/atalpandeyy/PythonProgramming/blob/main/Ques1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
price = float(input())
discount = float(input())
print(price * (1 - discount/100))
# Out:
# 63
# 56
# 27.719999999999995
